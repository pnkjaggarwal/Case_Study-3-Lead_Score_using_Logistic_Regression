# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Importing library

# %% [markdown]
# ## Data Loding and exploration

# %%
lead = pd.read_csv('Leads.csv')    # loading the data from csv to lead
lead.head()   # it will show my first five rows
# Out:
#                             Prospect ID  Lead Number              Lead Origin  \
# 0  7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737                      API
# 1  2a272436-5132-4136-86fa-dcc88c88f482       660728                      API
# 2  8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727  Landing Page Submission
# 3  0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719  Landing Page Submission
# 4  3256f628-e534-4826-9d63-4a8b88782852       660681  Landing Page Submission
#
#       Lead Source Do Not Email Do Not Call  Converted  TotalVisits  \
# 0      Olark Chat           No          No          0          0.0
# 1  Organic Search           No          No          0          5.0
# 2  Direct Traffic           No          No          1          2.0
# 3  Direct Traffic           No          No          0          1.0
# 4          Google           No          No          1          2.0
#
#    Total Time Spent on Website  Page Views Per Visit            Last Activity  \
# 0                            0                   0.0  Page Visited on Website
# 1                          674                   2.5             Email Opened
# 2                         1532                   2.0             Email Opened
# 3                          305                   1.0              Unreachable
# 4                         1428                   1.0        Converted to Lead
#
#   Country           Specialization How did you hear about X Education  \
# 0     NaN                   Select                             Select
# 1   India                   Select                             Select
# 2   India  Business Administration                             Select
# 3   India    Media and Advertising                      Word Of Mouth
# 4   India                   Select                              Other
#
#   What is your current occupation  \
# 0                      Unemployed
# 1                      Unemployed
# 2                         Student
# 3                      Unemployed
# 4                      Unemployed
#
#   What matters most to you in choosing a course Search Magazine  \
# 0                       Better Career Prospects     No       No
# 1                       Better Career Prospects     No       No
# 2                       Better Career Prospects     No       No
# 3                       Better Career Prospects     No       No
# 4                       Better Career Prospects     No       No
#
#   Newspaper Article X Education Forums Newspaper Digital Advertisement  \
# 0                No                 No        No                    No
# 1                No                 No        No                    No
# 2                No                 No        No                    No
# 3                No                 No        No                    No
# 4                No                 No        No                    No
#
#   Through Recommendations Receive More Updates About Our Courses  \
# 0                      No                                     No
# 1                      No                                     No
# 2                      No                                     No
# 3                      No                                     No
# 4                      No                                     No
#
#                                   Tags      Lead Quality  \
# 0          Interested in other courses  Low in Relevance
# 1                              Ringing               NaN
# 2  Will revert after reading the email          Might be
# 3                              Ringing          Not Sure
# 4  Will revert after reading the email          Might be
#
#   Update me on Supply Chain Content Get updates on DM Content    Lead Profile  \
# 0                                No                        No          Select
# 1                                No                        No          Select
# 2                                No                        No  Potential Lead
# 3                                No                        No          Select
# 4                                No                        No          Select
#
#      City Asymmetrique Activity Index Asymmetrique Profile Index  \
# 0  Select                   02.Medium                  02.Medium
# 1  Select                   02.Medium                  02.Medium
# 2  Mumbai                   02.Medium                    01.High
# 3  Mumbai                   02.Medium                    01.High
# 4  Mumbai                   02.Medium                    01.High
#
#    Asymmetrique Activity Score  Asymmetrique Profile Score  \
# 0                         15.0                        15.0
# 1                         15.0                        15.0
# 2                         14.0                        20.0
# 3                         13.0                        17.0
# 4                         15.0                        18.0
#
#   I agree to pay the amount through cheque  \
# 0                                       No
# 1                                       No
# 2                                       No
# 3                                       No
# 4                                       No
#
#   A free copy of Mastering The Interview Last Notable Activity
# 0                                     No              Modified
# 1                                     No          Email Opened
# 2                                    Yes          Email Opened
# 3                                     No              Modified
# 4                                     No              Modified

# %%
# First two columns are useless as every row is unique
lead.drop(['Lead Number', 'Prospect ID'], axis=1, inplace=True)

# %%
lead.shape   # it will give us the no. of rows and columns
# Out:
# (9240, 35)

# %%
lead.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9240 entries, 0 to 9239
# Data columns (total 35 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Lead Origin                                    9240 non-null   object
#  1   Lead Source                                    9204 non-null   object
#  2   Do Not Email                                   9240 non-null   object
#  3   Do Not Call                                    9240 non-null   object
#  4   Converted                                      9240 non-null   int64
#  5   TotalVisits                                    9103 non-null   float64
#  6   Total Time Spent on Website                    9240 non-null   int64
#  7   Page Views Per Visit                           9103 non-null   float64
#  8   Last Activity                                  9137 non-null   object
#  9   Country                                        6779 non-null   object
#  10  Specialization                                 7802 non-null   object
#  11  How did you hear about X Education             7033 non-null   object
#  12  What is your current occupation                6550 non-null   object
#  13  What matters most to you in choosing a course  6531 non-null   object
#  14  Search                                         9240 non-null   object
#  15  Magazine                                       9240 non-null   object
#  16  Newspaper Article                              9240 non-null   object
#  17  X Education Forums                             9240 non-null   object
#  18  Newspaper                                      9240 non-null   object
#  19  Digital Advertisement                          9240 non-null   object
#  20  Through Recommendations                        9240 non-null   object
#  21  Receive More Updates About Our Courses         9240 non-null   object
#  22  Tags                                           5887 non-null   object
#  23  Lead Quality                                   4473 non-null   object
#  24  Update me on Supply Chain Content              9240 non-null   object
#  25  Get updates on DM Content                      9240 non-null   object
#  26  Lead Profile                                   6531 non-null   object
#  27  City                                           7820 non-null   object
#  28  Asymmetrique Activity Index                    5022 non-null   object
#  29  Asymmetrique Profile Index                     5022 non-null   object
#  30  Asymmetrique Activity Score                    5022 non-null   float64
#  31  Asymmetrique Profile Score                     5022 non-null   float64
#  32  I agree to pay the amount through cheque       9240 non-null   object
#  33  A free copy of Mastering The Interview         9240 non-null   object
#  34  Last Notable Activity                          9240 non-null   object
# dtypes: float64(4), int64(2), object(29)
# memory usage: 2.5+ MB

# %%
lead.describe()
# Out:
#          Converted  TotalVisits  Total Time Spent on Website  \
# count  9240.000000  9103.000000                  9240.000000
# mean      0.385390     3.445238                   487.698268
# std       0.486714     4.854853                   548.021466
# min       0.000000     0.000000                     0.000000
# 25%       0.000000     1.000000                    12.000000
# 50%       0.000000     3.000000                   248.000000
# 75%       1.000000     5.000000                   936.000000
# max       1.000000   251.000000                  2272.000000
#
#        Page Views Per Visit  Asymmetrique Activity Score  \
# count           9103.000000                  5022.000000
# mean               2.362820                    14.306252
# std                2.161418                     1.386694
# min                0.000000                     7.000000
# 25%                1.000000                    14.000000
# 50%                2.000000                    14.000000
# 75%                3.000000                    15.000000
# max               55.000000                    18.000000
#
#        Asymmetrique Profile Score
# count                 5022.000000
# mean                    16.344883
# std                      1.811395
# min                     11.000000
# 25%                     15.000000
# 50%                     16.000000
# 75%                     18.000000
# max                     20.000000

# %%
sns.heatmap(lead.corr())

# %%
lead.isna().sum()
# Out:
# Lead Origin                                         0
# Lead Source                                        36
# Do Not Email                                        0
# Do Not Call                                         0
# Converted                                           0
# TotalVisits                                       137
# Total Time Spent on Website                         0
# Page Views Per Visit                              137
# Last Activity                                     103
# Country                                          2461
# Specialization                                   1438
# How did you hear about X Education               2207
# What is your current occupation                  2690
# What matters most to you in choosing a course    2709
# Search                                              0
# Magazine                                            0
# Newspaper Article                                   0
# X Education Forums                                  0
# Newspaper                                           0
# Digital Advertisement                               0
# Through Recommendations                             0
# Receive More Updates About Our Courses              0
# Tags                                             3353
# Lead Quality                                     4767
# Update me on Supply Chain Content                   0
# Get updates on DM Content                           0
# Lead Profile                                     2709
# City                                             1420
# Asymmetrique Activity Index                      4218
# Asymmetrique Profile Index                       4218
# Asymmetrique Activity Score                      4218
# Asymmetrique Profile Score                       4218
# I agree to pay the amount through cheque            0
# A free copy of Mastering The Interview              0
# Last Notable Activity                               0
# dtype: int64

# %%
plt.figure(figsize=[20,10])
sns.heatmap(lead.isna(), cbar=False, yticklabels=False, cmap='coolwarm')
plt.show()

# %% [markdown]
# ## Data Analysis and Cleaning

# %%
cat = lead.select_dtypes(include=['int64', 'object'])
cat.drop(['Total Time Spent on Website'], axis=1, inplace=True)

# %%
lead['Converted'].value_counts().plot.bar()
lead['Converted'].value_counts()
# Out:
# 0    5679
# 1    3561
# Name: Converted, dtype: int64

# %%
for i in cat.columns:
    plt.figure(figsize=[20,10])
    sns.countplot(x=i, hue='Converted', data=cat)
    plt.xlabel(i)
    plt.tick_params('x', rotation=45)
    plt.show()
    print(lead.groupby(['Converted',i])[i].count())
    print(lead[i].isna().sum())
# Out:
# Converted  Lead Origin
# 0          API                        2465
#            Landing Page Submission    3118
#            Lead Add Form                54
#            Lead Import                  42
# 1          API                        1115
#            Landing Page Submission    1768
#            Lead Add Form               664
#            Lead Import                  13
#            Quick Add Form                1
# Name: Lead Origin, dtype: int64
# 0
# Converted  Lead Source
# 0          Click2call              1
#            Direct Traffic       1725
#            Facebook               42
#            Google               1721
#            Olark Chat           1307
#            Organic Search        718
#            Pay per Click Ads       1
#            Press_Release           2
#            Reference              44
#            Referral Sites         94
#            Social Media            1
#            Welingak Website        2
#            bing                    5
#            blog                    1
#            google                  5
#            testone                 1
#            welearnblog_Home        1
#            youtubechannel          1
# 1          Click2call              3
#            Direct Traffic        818
#            Facebook               13
#            Google               1147
#            Live Chat               2
#            NC_EDM                  1
#            Olark Chat            448
#            Organic Search        436
#            Reference             490
#            Referral Sites         31
#            Social Media            1
#            WeLearn                 1
#            Welingak Website      140
#            bing                    1
# Name: Lead Source, dtype: int64
# 36
# Converted  Do Not Email
# 0          No              5063
#            Yes              616
# 1          No              3443
#            Yes              118
# Name: Do Not Email, dtype: int64
# 0
# Converted  Do Not Call
# 0          No             5679
# 1          No             3559
#            Yes               2
# Name: Do Not Call, dtype: int64
# 0
# Converted  Converted
# 0          0            5679
# 1          1            3561
# Name: Converted, dtype: int64
# 0
# Converted  Last Activity
# 0          Converted to Lead                374
#            Email Bounced                    300
#            Email Link Clicked               194
#            Email Opened                    2184
#            Form Submitted on Website         88
#            Had a Phone Conversation           8
#            Olark Chat Conversation          889
#            Page Visited on Website          489
#            SMS Sent                        1018
#            Unreachable                       62
#            Unsubscribed                      45
#            View in browser link Clicked       5
#            Visited Booth in Tradeshow         1
# 1          Approached upfront                 9
#            Converted to Lead                 54
#            Email Bounced                     26
#            Email Link Clicked                73
#            Email Marked Spam                  2
#            Email Opened                    1253
#            Email Received                     2
#            Form Submitted on Website         28
#            Had a Phone Conversation          22
#            Olark Chat Conversation           84
#            Page Visited on Website          151
#            Resubscribed to emails             1
#            SMS Sent                        1727
#            Unreachable                       31
#            Unsubscribed                      16
#            View in browser link Clicked       1
# Name: Last Activity, dtype: int64
# 103
# Converted  Country
# 0          Asia/Pacific Region        1
#            Australia                 10
#            Bahrain                    3
#            Bangladesh                 1
#            Belgium                    2
#            Canada                     4
#            China                      2
#            France                     3
#            Germany                    3
#            Ghana                      2
#            Hong Kong                  3
#            India                   4091
#            Indonesia                  1
#            Italy                      2
#            Kenya                      1
#            Kuwait                     4
#            Liberia                    1
#            Malaysia                   1
#            Netherlands                1
#            Nigeria                    4
#            Oman                       3
#            Philippines                2
#            Qatar                      9
#            Russia                     1
#            Saudi Arabia              17
#            Singapore                 13
#            South Africa               3
#            Sri Lanka                  1
#            Sweden                     2
#            Switzerland                1
#            Tanzania                   1
#            Uganda                     2
#            United Arab Emirates      33
#            United Kingdom            10
#            United States             51
#            Vietnam                    1
#            unknown                    4
# 1          Asia/Pacific Region        1
#            Australia                  3
#            Bahrain                    4
#            Bangladesh                 1
#            Denmark                    1
#            France                     3
#            Germany                    1
#            Hong Kong                  4
#            India                   2401
#            Netherlands                1
#            Oman                       3
#            Qatar                      1
#            Saudi Arabia               4
#            Singapore                 11
#            South Africa               1
#            Sweden                     1
#            United Arab Emirates      20
#            United Kingdom             5
#            United States             18
#            unknown                    1
# Name: Country, dtype: int64
# 2461
# Converted  Specialization
# 0          Banking, Investment And Insurance     171
#            Business Administration               224
#            E-Business                             36
#            E-COMMERCE                             72
#            Finance Management                    540
#            Healthcare Management                  80
#            Hospitality Management                 66
#            Human Resource Management             460
#            IT Projects Management                226
#            International Business                114
#            Marketing Management                  430
#            Media and Advertising                 118
#            Operations Management                 265
#            Retail Management                      66
#            Rural and Agribusiness                 42
#            Select                               1124
#            Services Excellence                    29
#            Supply Chain Management               198
#            Travel and Tourism                    131
# 1          Banking, Investment And Insurance     167
#            Business Administration               179
#            E-Business                             21
#            E-COMMERCE                             40
#            Finance Management                    436
#            Healthcare Management                  79
#            Hospitality Management                 48
#            Human Resource Management             388
#            IT Projects Management                140
#            International Business                 64
#            Marketing Management                  408
#            Media and Advertising                  85
#            Operations Management                 238
#            Retail Management                      34
#            Rural and Agribusiness                 31
#            Select                                818
#            Services Excellence                    11
#            Supply Chain Management               151
#            Travel and Tourism                     72
# Name: Specialization, dtype: int64
# 1438
# Converted  How did you hear about X Education
# 0          Advertisements                          38
#            Email                                   13
#            Multiple Sources                        96
#            Online Search                          465
#            Other                                  111
#            SMS                                     18
#            Select                                2612
#            Social Media                            39
#            Student of SomeSchool                  167
#            Word Of Mouth                          196
# 1          Advertisements                          32
#            Email                                   13
#            Multiple Sources                        56
#            Online Search                          343
#            Other                                   75
#            SMS                                      5
#            Select                                2431
#            Social Media                            28
#            Student of SomeSchool                  143
#            Word Of Mouth                          152
# Name: How did you hear about X Education, dtype: int64
# 2207
# Converted  What is your current occupation
# 0          Businessman                           3
#            Other                                 6
#            Student                             132
#            Unemployed                         3159
#            Working Professional                 59
# 1          Businessman                           5
#            Housewife                            10
#            Other                                10
#            Student                              78
#            Unemployed                         2441
#            Working Professional                647
# Name: What is your current occupation, dtype: int64
# 2690
# Converted  What matters most to you in choosing a course
# 0          Better Career Prospects                          3338
#            Flexibility & Convenience                           1
#            Other                                               1
# 1          Better Career Prospects                          3190
#            Flexibility & Convenience                           1
# Name: What matters most to you in choosing a course, dtype: int64
# 2709
# Converted  Search
# 0          No        5670
#            Yes          9
# 1          No        3556
#            Yes          5
# Name: Search, dtype: int64
# 0
# Converted  Magazine
# 0          No          5679
# 1          No          3561
# Name: Magazine, dtype: int64
# 0
# Converted  Newspaper Article
# 0          No                   5678
#            Yes                     1
# 1          No                   3560
#            Yes                     1
# Name: Newspaper Article, dtype: int64
# 0
# Converted  X Education Forums
# 0          No                    5678
#            Yes                      1
# 1          No                    3561
# Name: X Education Forums, dtype: int64
# 0
# Converted  Newspaper
# 0          No           5678
#            Yes             1
# 1          No           3561
# Name: Newspaper, dtype: int64
# 0
# Converted  Digital Advertisement
# 0          No                       5676
#            Yes                         3
# 1          No                       3560
#            Yes                         1
# Name: Digital Advertisement, dtype: int64
# 0
# Converted  Through Recommendations
# 0          No                         5677
#            Yes                           2
# 1          No                         3556
#            Yes                           5
# Name: Through Recommendations, dtype: int64
# 0
# Converted  Receive More Updates About Our Courses
# 0          No                                        5679
# 1          No                                        3561
# Name: Receive More Updates About Our Courses, dtype: int64
# 0
# Converted  Tags
# 0          Already a student                                     462
#            Busy                                                   81
#            Closed by Horizzon                                      2
#            Diploma holder (Not Eligible)                          62
#            Graduation in progress                                104
#            In confusion whether part time or DLP                   4
#            Interested  in full time MBA                          114
#            Interested in other courses                           500
#            Lost to EINS                                            4
#            Lost to Others                                          7
#            Not doing further education                           144
#            Recognition issue (DEC approval)                        1
#            Ringing                                              1169
#            Shall take in the next coming month                     1
#            Still Thinking                                          5
#            University not recognized                               2
#            Want to take admission but has financial problems       4
#            Will revert after reading the email                    65
#            in touch with EINS                                      9
#            invalid number                                         82
#            number not provided                                    27
#            opp hangup                                             30
#            switched off                                          236
#            wrong number given                                     47
# 1          Already a student                                       3
#            Busy                                                  105
#            Closed by Horizzon                                    356
#            Diploma holder (Not Eligible)                           1
#            Graduation in progress                                  7
#            In confusion whether part time or DLP                   1
#            Interested  in full time MBA                            3
#            Interested in Next batch                                5
#            Interested in other courses                            13
#            Lateral student                                         3
#            Lost to EINS                                          171
#            Not doing further education                             1
#            Ringing                                                34
#            Shall take in the next coming month                     1
#            Still Thinking                                          1
#            Want to take admission but has financial problems       2
#            Will revert after reading the email                  2007
#            in touch with EINS                                      3
#            invalid number                                          1
#            opp hangup                                              3
#            switched off                                            4
# Name: Tags, dtype: int64
# 3353
# Converted  Lead Quality
# 0          High in Relevance      34
#            Low in Relevance      106
#            Might be              381
#            Not Sure              826
#            Worst                 589
# 1          High in Relevance     603
#            Low in Relevance      477
#            Might be             1179
#            Not Sure              266
#            Worst                  12
# Name: Lead Quality, dtype: int64
# 4767
# Converted  Update me on Supply Chain Content
# 0          No                                   5679
# 1          No                                   3561
# Name: Update me on Supply Chain Content, dtype: int64
# 0
# Converted  Get updates on DM Content
# 0          No                           5679
# 1          No                           3561
# Name: Get updates on DM Content, dtype: int64
# 0
# Converted  Lead Profile
# 0          Lateral Student                   1
#            Other Leads                     307
#            Potential Lead                  346
#            Select                         2454
#            Student of SomeSchool           232
# 1          Dual Specialization Student      20
#            Lateral Student                  23
#            Other Leads                     180
#            Potential Lead                 1267
#            Select                         1692
#            Student of SomeSchool             9
# Name: Lead Profile, dtype: int64
# 2709
# Converted  City
# 0          Mumbai                         1913
#            Other Cities                    410
#            Other Cities of Maharashtra     256
#            Other Metro Cities              225
#            Select                         1146
#            Thane & Outskirts               414
#            Tier II Cities                   49
# 1          Mumbai                         1309
#            Other Cities                    276
#            Other Cities of Maharashtra     201
#            Other Metro Cities              155
#            Select                         1103
#            Thane & Outskirts               338
#            Tier II Cities                   25
# Name: City, dtype: int64
# 1420
# Converted  Asymmetrique Activity Index
# 0          01.High                         576
#            02.Medium                      2209
#            03.Low                          329
# 1          01.High                         245
#            02.Medium                      1630
#            03.Low                           33
# Name: Asymmetrique Activity Index, dtype: int64
# 4218
# Converted  Asymmetrique Profile Index
# 0          01.High                       1158
#            02.Medium                     1940
#            03.Low                          16
# 1          01.High                       1045
#            02.Medium                      848
#            03.Low                          15
# Name: Asymmetrique Profile Index, dtype: int64
# 4218
# Converted  I agree to pay the amount through cheque
# 0          No                                          5679
# 1          No                                          3561
# Name: I agree to pay the amount through cheque, dtype: int64
# 0
# Converted  A free copy of Mastering The Interview
# 0          No                                        3821
#            Yes                                       1858
# 1          No                                        2531
#            Yes                                       1030
# Name: A free copy of Mastering The Interview, dtype: int64
# 0
# Converted  Last Notable Activity
# 0          Email Bounced                     51
#            Email Link Clicked               128
#            Email Opened                    1783
#            Form Submitted on Website          1
#            Had a Phone Conversation           1
#            Modified                        2624
#            Olark Chat Conversation          158
#            Page Visited on Website          225
#            SMS Sent                         664
#            Unreachable                       10
#            Unsubscribed                      33
#            View in browser link Clicked       1
# 1          Approached upfront                 1
#            Email Bounced                      9
#            Email Link Clicked                45
#            Email Marked Spam                  2
#            Email Opened                    1044
#            Email Received                     1
#            Had a Phone Conversation          13
#            Modified                         783
#            Olark Chat Conversation           25
#            Page Visited on Website           93
#            Resubscribed to emails             1
#            SMS Sent                        1508
#            Unreachable                       22
#            Unsubscribed                      14
# Name: Last Notable Activity, dtype: int64
# 0

# %%
# These are the leads which have more than 99.99% data in one category

lead.drop(['I agree to pay the amount through cheque','Get updates on DM Content','Receive More Updates About Our Courses',
          'Update me on Supply Chain Content', 'Magazine','What matters most to you in choosing a course',
           'Search', 'Through Recommendations','Do Not Call', 'Newspaper',
           'X Education Forums','Newspaper Article','Country','Digital Advertisement',
           'Tags'], axis=1, inplace=True)

# %%
# These are the leads having high missing data with no relevant information or are already covered by other feature
lead.drop(['Lead Profile','Specialization', 'How did you hear about X Education', 'City','Last Notable Activity'], axis=1, inplace=True)

# %%
lead['Lead Source'] = lead['Lead Source'].replace({'Reference':'Other','Welingak Website':'Other',
                                                   'Referral Sites':'Other','Facebook':'Other','bing':'Other',
                                                   'google':'Other','Click2call':'Other','Press_Release':'Other',
                                                   'Live Chat':'Other','Social Media':'Other','WeLearn':'Other',
                                                   'Pay per Click Ads':'Other','youtubechannel':'Other',
                                                   'welearnblog_Home':'Other',
                                                   'NC_EDM':'Other','blog':'Other','testone':'Other'})
lead['Last Activity']=lead['Last Activity'].replace({'Converted to Lead':'Other','Email Bounced':'Other',
                                                     'Email Link Clicked':'Other','Form Submitted on Website':'Other',
                                                     'Unreachable':'Other','Unsubscribed':'Other',
                                                     'Had a Phone Conversation':'Other','Approached upfront':'Other',
                                                     'View in browser link Clicked':'Other','Email Marked Spam':'Other',
                                                     'Email Received':'Other','Visited Booth in Tradeshow':'Other',
                                                     'Resubscribed to emails':'Other'})

# %%
lead = lead[lead['Lead Source'].isna()==False]
lead = lead[lead['Last Activity'].isna()==False]

# %%
lead['What is your current occupation']=lead['What is your current occupation'].replace({'Student':'Other','Other':'Other',
                                                                                         'Housewife':'Other','Businessman':'Other'})

# %%
lead = lead[lead['What is your current occupation'].isna()==False]

# %%
lead = lead[lead['TotalVisits'].isna()==False]

# %%
lead.shape
# Out:
# (6391, 15)

# %%
lead.isna().sum()
# Out:
# Lead Origin                                  0
# Lead Source                                  0
# Do Not Email                                 0
# Converted                                    0
# TotalVisits                                  0
# Total Time Spent on Website                  0
# Page Views Per Visit                         0
# Last Activity                                0
# What is your current occupation              0
# Lead Quality                              2037
# Asymmetrique Activity Index               2903
# Asymmetrique Profile Index                2903
# Asymmetrique Activity Score               2903
# Asymmetrique Profile Score                2903
# A free copy of Mastering The Interview       0
# dtype: int64

# %%
cat = lead.select_dtypes(include=['int64', 'object'])
cat.drop(['Total Time Spent on Website'], axis=1, inplace=True)

# %%
for i in cat.columns:
    plt.figure(figsize=[20,10])
    sns.countplot(x=i, hue='Converted', data=cat)
    plt.xlabel(i)
    plt.tick_params('x', rotation=45)
    plt.show()
    print(lead.groupby([i,'Converted'])[i].count()/lead.shape[0]*100)
    print(lead[i].isna().sum()/lead.shape[0]*100)
# Out:
# Lead Origin              Converted
# API                      0            18.557346
#                          1            14.927241
# Landing Page Submission  0            32.624003
#                          1            24.378032
# Lead Add Form            0             0.578939
#                          1             8.511970
# Lead Import              0             0.281646
#                          1             0.140823
# Name: Lead Origin, dtype: float64
# 0.0
# Lead Source     Converted
# Direct Traffic  0            18.526052
#                 1            11.062432
# Google          0            16.163355
#                 1            15.881709
# Olark Chat      0             8.011266
#                 1             5.945861
# Organic Search  0             7.651385
#                 1             5.961508
# Other           0             1.689876
#                 1             9.106556
# Name: Lead Source, dtype: float64
# 0.0
# Do Not Email  Converted
# No            0            46.471601
#               1            46.549836
# Yes           0             5.570333
#               1             1.408230
# Name: Do Not Email, dtype: float64
# 0.0
# Converted  Converted
# 0          0            52.041934
# 1          1            47.958066
# Name: Converted, dtype: float64
# 0.0
# Last Activity            Converted
# Email Opened             0            20.481928
#                          1            17.931466
# Olark Chat Conversation  0             5.523392
#                          1             1.173525
# Other                    0            10.420904
#                          1             3.489282
# Page Visited on Website  0             4.584572
#                          1             2.127992
# SMS Sent                 0            11.031138
#                          1            23.235800
# Name: Last Activity, dtype: float64
# 0.0
# What is your current occupation  Converted
# Other                            0             2.206228
#                                  1             1.517759
# Unemployed                       0            48.975121
#                                  1            36.707870
# Working Professional             0             0.860585
#                                  1             9.732436
# Name: What is your current occupation, dtype: float64
# 0.0
# Lead Quality       Converted
# High in Relevance  0             0.531998
#                    1             8.731028
# Low in Relevance   0             1.580347
#                    1             7.119387
# Might be           0             5.773744
#                    1            17.994054
# Not Sure           0            12.830543
#                    1             4.162103
# Worst              0             9.216085
#                    1             0.187764
# Name: Lead Quality, dtype: float64
# 31.87294633077766
# Asymmetrique Activity Index  Converted
# 01.High                      0             2.863402
#                              1             3.411047
# 02.Medium                    0            21.420748
#                              1            22.516038
# 03.Low                       0             3.958692
#                              1             0.406822
# Name: Asymmetrique Activity Index, dtype: float64
# 45.42325144734784
# Asymmetrique Profile Index  Converted
# 01.High                     0            12.157722
#                             1            14.723830
# 02.Medium                   0            15.913003
#                             1            11.391019
# 03.Low                      0             0.172117
#                             1             0.219058
# Name: Asymmetrique Profile Index, dtype: float64
# 45.42325144734784
# A free copy of Mastering The Interview  Converted
# No                                      0            32.170239
#                                         1            33.860116
# Yes                                     0            19.871695
#                                         1            14.097950
# Name: A free copy of Mastering The Interview, dtype: float64
# 0.0

# %%
lead.isna().sum()/lead.shape[0]*100
# Out:
# Lead Origin                                0.000000
# Lead Source                                0.000000
# Do Not Email                               0.000000
# Converted                                  0.000000
# TotalVisits                                0.000000
# Total Time Spent on Website                0.000000
# Page Views Per Visit                       0.000000
# Last Activity                              0.000000
# What is your current occupation            0.000000
# Lead Quality                              31.872946
# Asymmetrique Activity Index               45.423251
# Asymmetrique Profile Index                45.423251
# Asymmetrique Activity Score               45.423251
# Asymmetrique Profile Score                45.423251
# A free copy of Mastering The Interview     0.000000
# dtype: float64

# %%
lead.shape
# Out:
# (6391, 15)

# %%
# These are the leads which have more than 30% of data missing
for i in lead.columns:
    if lead[i].isna().sum()/lead.shape[0]>0.3:
        lead.drop(i, axis=1, inplace=True)

# %%
lead.shape
# Out:
# (6391, 10)

# %%
lead.isna().sum()/lead.shape[0]*100
# Out:
# Lead Origin                               0.0
# Lead Source                               0.0
# Do Not Email                              0.0
# Converted                                 0.0
# TotalVisits                               0.0
# Total Time Spent on Website               0.0
# Page Views Per Visit                      0.0
# Last Activity                             0.0
# What is your current occupation           0.0
# A free copy of Mastering The Interview    0.0
# dtype: float64

# %%
cont = lead.select_dtypes(exclude=[object])
sns.pairplot(cont, hue='Converted', data=cont)

# %% [markdown]
# - As we can see there are some outliers in our continuous variable lets remove them

# %%
cont.columns
# Out:
# Index(['Converted', 'TotalVisits', 'Total Time Spent on Website',
#        'Page Views Per Visit'],
#       dtype='object')

# %%
sns.boxplot(x='TotalVisits', data=cont)
print(cont['TotalVisits'].quantile(.250), cont['TotalVisits'].quantile(.75))
print((1-(1.5*4)), (5+(1.5*4)))
# Out:
# 1.0 5.0
# -5.0 11.0

# %%
sns.boxplot(x='Total Time Spent on Website', data=cont)
print(cont['Total Time Spent on Website'].quantile(.250), cont['Total Time Spent on Website'].quantile(.75))
print((34.5-(1.5*(1148-34.5))), (1148+(1.5*(1148-34.5))))
# Out:
# 34.5 1021.5
# -1635.75 2818.25

# %%
sns.boxplot(x='Page Views Per Visit', data=cont)
print(cont['Page Views Per Visit'].quantile(.250), cont['Page Views Per Visit'].quantile(.75))
print((1-(1.5*3)), (4+(1.5*3)))
# Out:
# 1.0 3.5
# -3.5 8.5

# %%
lead.shape
# Out:
# (6391, 10)

# %%
lead = lead[lead['Page Views Per Visit']>=-3.5]
lead = lead[lead['Page Views Per Visit']<=8.5]

# %%
lead.shape
# Out:
# (6302, 10)

# %%
lead = lead[lead['TotalVisits']>=-5]
lead = lead[lead['TotalVisits']<=11]

# %%
lead.shape
# Out:
# (6119, 10)

# %%
lead = lead[lead['Total Time Spent on Website']>=-1635.75]
lead = lead[lead['Total Time Spent on Website']<=2818.25]

# %%
lead.shape
# Out:
# (6119, 10)

# %%
6119/9240
# Out:
# 0.6622294372294373

# %% [markdown]
# - Our Data is cleaned and now we can use models to assign lead scores

# %% [markdown]
# ## Data Transformation, Feature Selection and Modeling

# %% [markdown]
# 1. Create Dummy Variables

# %%
lead.head()
# Out:
#                Lead Origin     Lead Source Do Not Email  Converted  \
# 0                      API      Olark Chat           No          0
# 1                      API  Organic Search           No          0
# 2  Landing Page Submission  Direct Traffic           No          1
# 3  Landing Page Submission  Direct Traffic           No          0
# 4  Landing Page Submission          Google           No          1
#
#    TotalVisits  Total Time Spent on Website  Page Views Per Visit  \
# 0          0.0                            0                   0.0
# 1          5.0                          674                   2.5
# 2          2.0                         1532                   2.0
# 3          1.0                          305                   1.0
# 4          2.0                         1428                   1.0
#
#              Last Activity What is your current occupation  \
# 0  Page Visited on Website                      Unemployed
# 1             Email Opened                      Unemployed
# 2             Email Opened                           Other
# 3                    Other                      Unemployed
# 4                    Other                      Unemployed
#
#   A free copy of Mastering The Interview
# 0                                     No
# 1                                     No
# 2                                    Yes
# 3                                     No
# 4                                     No

# %%
temp = lead.select_dtypes(include=['object'])
temp.head()
# Out:
#                Lead Origin     Lead Source Do Not Email  \
# 0                      API      Olark Chat           No
# 1                      API  Organic Search           No
# 2  Landing Page Submission  Direct Traffic           No
# 3  Landing Page Submission  Direct Traffic           No
# 4  Landing Page Submission          Google           No
#
#              Last Activity What is your current occupation  \
# 0  Page Visited on Website                      Unemployed
# 1             Email Opened                      Unemployed
# 2             Email Opened                           Other
# 3                    Other                      Unemployed
# 4                    Other                      Unemployed
#
#   A free copy of Mastering The Interview
# 0                                     No
# 1                                     No
# 2                                    Yes
# 3                                     No
# 4                                     No

# %%
temp.columns
# Out:
# Index(['Lead Origin', 'Lead Source', 'Do Not Email', 'Last Activity',
#        'What is your current occupation',
#        'A free copy of Mastering The Interview'],
#       dtype='object')

# %%
temp = pd.get_dummies(temp,drop_first=True)

# %%
temp.head(2)
# Out:
#    Lead Origin_Landing Page Submission  Lead Origin_Lead Add Form  \
# 0                                    0                          0
# 1                                    0                          0
#
#    Lead Origin_Lead Import  Lead Source_Google  Lead Source_Olark Chat  \
# 0                        0                   0                       1
# 1                        0                   0                       0
#
#    Lead Source_Organic Search  Lead Source_Other  Do Not Email_Yes  \
# 0                           0                  0                 0
# 1                           1                  0                 0
#
#    Last Activity_Olark Chat Conversation  Last Activity_Other  \
# 0                                      0                    0
# 1                                      0                    0
#
#    Last Activity_Page Visited on Website  Last Activity_SMS Sent  \
# 0                                      1                       0
# 1                                      0                       0
#
#    What is your current occupation_Unemployed  \
# 0                                           1
# 1                                           1
#
#    What is your current occupation_Working Professional  \
# 0                                                  0
# 1                                                  0
#
#    A free copy of Mastering The Interview_Yes
# 0                                           0
# 1                                           0

# %%
lead.drop(['Lead Origin', 'Lead Source', 'Do Not Email', 'Last Activity',
       'What is your current occupation',
       'A free copy of Mastering The Interview'], axis =1, inplace=True)

# %%
lead= pd.concat([lead, temp], axis=1)

# %%
lead.head(2)
# Out:
#    Converted  TotalVisits  Total Time Spent on Website  Page Views Per Visit  \
# 0          0          0.0                            0                   0.0
# 1          0          5.0                          674                   2.5
#
#    Lead Origin_Landing Page Submission  Lead Origin_Lead Add Form  \
# 0                                    0                          0
# 1                                    0                          0
#
#    Lead Origin_Lead Import  Lead Source_Google  Lead Source_Olark Chat  \
# 0                        0                   0                       1
# 1                        0                   0                       0
#
#    Lead Source_Organic Search  Lead Source_Other  Do Not Email_Yes  \
# 0                           0                  0                 0
# 1                           1                  0                 0
#
#    Last Activity_Olark Chat Conversation  Last Activity_Other  \
# 0                                      0                    0
# 1                                      0                    0
#
#    Last Activity_Page Visited on Website  Last Activity_SMS Sent  \
# 0                                      1                       0
# 1                                      0                       0
#
#    What is your current occupation_Unemployed  \
# 0                                           1
# 1                                           1
#
#    What is your current occupation_Working Professional  \
# 0                                                  0
# 1                                                  0
#
#    A free copy of Mastering The Interview_Yes
# 0                                           0
# 1                                           0

# %%
lead.shape
# Out:
# (6119, 19)

# %%
X = lead.iloc[:, 1:]
y = lead.iloc[:,0]
print(X.shape, y.shape)
# Out:
# (6119, 18) (6119,)

# %% [markdown]
# 2.1 Logistic Regression without feature selection and without standardizing

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0, stratify=y)

# %%
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
# Out:
# (4283, 18) (1836, 18) (4283,) (1836,)

# %%
y_test = y_test.values.reshape(-1,1)

# %%
Lreg = LogisticRegression()
Lreg.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_predict_test = Lreg.predict(x_test)
y_predict_train = Lreg.predict(x_train)

# %%
score_test = accuracy_score(y_test, y_predict_test)
score_train = accuracy_score(y_train, y_predict_train)

# %%
print('Test score: ',score_test)
print('Train score', score_train)
# Out:
# Test score:  0.7870370370370371
# Train score 0.7812281111370535

# %%
from sklearn.metrics import classification_report
report = classification_report(y_test, y_predict_test)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.83      0.80       958
#            1       0.80      0.74      0.77       878
#
#     accuracy                           0.79      1836
#    macro avg       0.79      0.79      0.79      1836
# weighted avg       0.79      0.79      0.79      1836

# %%
from sklearn.metrics import confusion_matrix

# %%
matrix = confusion_matrix(y_test, y_predict_test)

# %%
matrix
# Out:
# array([[792, 166],
#        [225, 653]], dtype=int64)

# %%
import statsmodels.api as sm

# %%
x = sm.add_constant(X)
model = sm.Logit(y, x).fit()
model.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.456675
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              Converted   No. Observations:                 6119
# Model:                          Logit   Df Residuals:                     6100
# Method:                           MLE   Df Model:                           18
# Date:                Thu, 28 Jan 2021   Pseudo R-squ.:                  0.3402
# Time:                        22:15:48   Log-Likelihood:                -2794.4
# converged:                       True   LL-Null:                       -4235.5
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ========================================================================================================================
#                                                            coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------
# const                                                   -2.1697      0.219     -9.886      0.000      -2.600      -1.740
# TotalVisits                                              0.1729      0.022      8.010      0.000       0.131       0.215
# Total Time Spent on Website                              0.0019   7.13e-05     27.235      0.000       0.002       0.002
# Page Views Per Visit                                    -0.1251      0.031     -4.039      0.000      -0.186      -0.064
# Lead Origin_Landing Page Submission                     -0.1764      0.103     -1.719      0.086      -0.378       0.025
# Lead Origin_Lead Add Form                                4.1342      0.358     11.560      0.000       3.433       4.835
# Lead Origin_Lead Import                                  0.9566      0.534      1.791      0.073      -0.090       2.004
# Lead Source_Google                                       0.3764      0.109      3.449      0.001       0.163       0.590
# Lead Source_Olark Chat                                   1.7997      0.159     11.304      0.000       1.488       2.112
# Lead Source_Organic Search                               0.0918      0.124      0.740      0.460      -0.151       0.335
# Lead Source_Other                                        0.1553      0.314      0.495      0.620      -0.459       0.770
# Do Not Email_Yes                                        -1.2030      0.169     -7.126      0.000      -1.534      -0.872
# Last Activity_Olark Chat Conversation                   -1.4756      0.164     -9.021      0.000      -1.796      -1.155
# Last Activity_Other                                     -0.5091      0.115     -4.427      0.000      -0.734      -0.284
# Last Activity_Page Visited on Website                   -0.6489      0.155     -4.180      0.000      -0.953      -0.345
# Last Activity_SMS Sent                                   1.0138      0.077     13.141      0.000       0.863       1.165
# What is your current occupation_Unemployed              -0.1037      0.174     -0.596      0.551      -0.445       0.237
# What is your current occupation_Working Professional     2.3915      0.231     10.355      0.000       1.939       2.844
# A free copy of Mastering The Interview_Yes              -0.0331      0.103     -0.322      0.747      -0.234       0.168
# ========================================================================================================================
# """

# %% [markdown]
# - As we can see some features have high p value so we need to either drop them or use feature selection

# %% [markdown]
# 2.2 Logistic Regression without Feature Selection with Standardization

# %%
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
x_train[['TotalVisits', 'Total Time Spent on Website',
       'Page Views Per Visit']] = scale.fit_transform(x_train[['TotalVisits', 'Total Time Spent on Website',
       'Page Views Per Visit']] )

# %%
x_train.head(2)
# Out:
#       TotalVisits  Total Time Spent on Website  Page Views Per Visit  \
# 7601    -0.419812                    -0.663811             -0.169580
# 5305     0.386129                    -0.412182              0.943592
#
#       Lead Origin_Landing Page Submission  Lead Origin_Lead Add Form  \
# 7601                                    1                          0
# 5305                                    1                          0
#
#       Lead Origin_Lead Import  Lead Source_Google  Lead Source_Olark Chat  \
# 7601                        0                   0                       0
# 5305                        0                   0                       0
#
#       Lead Source_Organic Search  Lead Source_Other  Do Not Email_Yes  \
# 7601                           0                  0                 0
# 5305                           0                  0                 0
#
#       Last Activity_Olark Chat Conversation  Last Activity_Other  \
# 7601                                      0                    0
# 5305                                      0                    0
#
#       Last Activity_Page Visited on Website  Last Activity_SMS Sent  \
# 7601                                      0                       1
# 5305                                      0                       0
#
#       What is your current occupation_Unemployed  \
# 7601                                           1
# 5305                                           1
#
#       What is your current occupation_Working Professional  \
# 7601                                                  0
# 5305                                                  0
#
#       A free copy of Mastering The Interview_Yes
# 7601                                           1
# 5305                                           1

# %%
Lreg.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
x_test[['TotalVisits', 'Total Time Spent on Website',
       'Page Views Per Visit']] = scale.fit_transform(x_test[['TotalVisits', 'Total Time Spent on Website',
       'Page Views Per Visit']] )

# %%
y_predict_test = Lreg.predict(x_test)
y_predict_train = Lreg.predict(x_train)

# %%
score_test = accuracy_score(y_test, y_predict_test)
score_train = accuracy_score(y_train, y_predict_train)

# %%
print('Test score: ',score_test)
print('Train score', score_train)
# Out:
# Test score:  0.7946623093681917
# Train score 0.7896334345085221

# %%
print(classification_report(y_test, y_predict_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.84      0.81       958
#            1       0.81      0.75      0.78       878
#
#     accuracy                           0.79      1836
#    macro avg       0.80      0.79      0.79      1836
# weighted avg       0.80      0.79      0.79      1836

# %% [markdown]
# - As we can see, there's no slight change after standardization

# %% [markdown]
# 3. Logistic regression with Feature Selection

# %%
from sklearn.feature_selection import RFE

# %%
rfe = RFE(Lreg, 12)
rfe.fit(x_train, y_train)
# Out:
# RFE(estimator=LogisticRegression(), n_features_to_select=12)

# %%
list(zip(x_train.columns,rfe.support_, rfe.ranking_))
# Out:
# [('TotalVisits', False, 4),
#  ('Total Time Spent on Website', True, 1),
#  ('Page Views Per Visit', False, 5),
#  ('Lead Origin_Landing Page Submission', False, 2),
#  ('Lead Origin_Lead Add Form', True, 1),
#  ('Lead Origin_Lead Import', False, 3),
#  ('Lead Source_Google', True, 1),
#  ('Lead Source_Olark Chat', True, 1),
#  ('Lead Source_Organic Search', False, 6),
#  ('Lead Source_Other', True, 1),
#  ('Do Not Email_Yes', True, 1),
#  ('Last Activity_Olark Chat Conversation', True, 1),
#  ('Last Activity_Other', True, 1),
#  ('Last Activity_Page Visited on Website', True, 1),
#  ('Last Activity_SMS Sent', True, 1),
#  ('What is your current occupation_Unemployed', True, 1),
#  ('What is your current occupation_Working Professional', True, 1),
#  ('A free copy of Mastering The Interview_Yes', False, 7)]

# %%
col = x_train.columns[rfe.support_]

# %%
x_train = x_train[col]

# %%
x_train.columns
# Out:
# Index(['Total Time Spent on Website', 'Lead Origin_Lead Add Form',
#        'Lead Source_Google', 'Lead Source_Olark Chat', 'Lead Source_Other',
#        'Do Not Email_Yes', 'Last Activity_Olark Chat Conversation',
#        'Last Activity_Other', 'Last Activity_Page Visited on Website',
#        'Last Activity_SMS Sent', 'What is your current occupation_Unemployed',
#        'What is your current occupation_Working Professional'],
#       dtype='object')

# %%
x = sm.add_constant(x_train)
model = sm.Logit(y_train, x).fit()
model.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.466183
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              Converted   No. Observations:                 4283
# Model:                          Logit   Df Residuals:                     4270
# Method:                           MLE   Df Model:                           12
# Date:                Thu, 28 Jan 2021   Pseudo R-squ.:                  0.3265
# Time:                        22:15:49   Log-Likelihood:                -1996.7
# converged:                       True   LL-Null:                       -2964.6
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ========================================================================================================================
#                                                            coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------
# const                                                   -0.8241      0.208     -3.960      0.000      -1.232      -0.416
# Total Time Spent on Website                              1.1231      0.047     23.675      0.000       1.030       1.216
# Lead Origin_Lead Add Form                                3.1590      0.344      9.193      0.000       2.486       3.833
# Lead Source_Google                                       0.4113      0.091      4.521      0.000       0.233       0.590
# Lead Source_Olark Chat                                   1.6703      0.127     13.189      0.000       1.422       1.919
# Lead Source_Other                                        0.7391      0.294      2.517      0.012       0.164       1.315
# Do Not Email_Yes                                        -1.2217      0.201     -6.064      0.000      -1.617      -0.827
# Last Activity_Olark Chat Conversation                   -1.4200      0.191     -7.429      0.000      -1.795      -1.045
# Last Activity_Other                                     -0.5952      0.134     -4.454      0.000      -0.857      -0.333
# Last Activity_Page Visited on Website                   -0.4638      0.179     -2.592      0.010      -0.815      -0.113
# Last Activity_SMS Sent                                   1.0026      0.091     11.021      0.000       0.824       1.181
# What is your current occupation_Unemployed              -0.2623      0.204     -1.283      0.200      -0.663       0.138
# What is your current occupation_Working Professional     2.1924      0.271      8.082      0.000       1.661       2.724
# ========================================================================================================================
# """

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif = pd.DataFrame()
vif['Features'] = x_train.columns
vif['VIF'] = [variance_inflation_factor(x_train.values, i) for i in range(x_train.shape[1])]
vif['VIF'] = round(vif['VIF'])
vif = vif.sort_values('VIF',ascending = False)
vif
# Out:
#                                              Features  VIF
# 1                           Lead Origin_Lead Add Form  6.0
# 4                                   Lead Source_Other  6.0
# 10         What is your current occupation_Unemployed  3.0
# 2                                  Lead Source_Google  2.0
# 3                              Lead Source_Olark Chat  2.0
# 9                              Last Activity_SMS Sent  2.0
# 0                         Total Time Spent on Website  1.0
# 5                                    Do Not Email_Yes  1.0
# 6               Last Activity_Olark Chat Conversation  1.0
# 7                                 Last Activity_Other  1.0
# 8               Last Activity_Page Visited on Website  1.0
# 11  What is your current occupation_Working Profes...  1.0

# %%
x_train.drop(['Lead Origin_Lead Add Form'], axis = 1, inplace=True)

# %%
vif = pd.DataFrame()
vif['Features'] = x_train.columns
vif['VIF'] = [variance_inflation_factor(x_train.values, i) for i in range(x_train.shape[1])]
vif['VIF'] = round(vif['VIF'])
vif = vif.sort_values('VIF',ascending = False)
vif
# Out:
#                                              Features  VIF
# 9          What is your current occupation_Unemployed  3.0
# 1                                  Lead Source_Google  2.0
# 2                              Lead Source_Olark Chat  2.0
# 8                              Last Activity_SMS Sent  2.0
# 0                         Total Time Spent on Website  1.0
# 3                                   Lead Source_Other  1.0
# 4                                    Do Not Email_Yes  1.0
# 5               Last Activity_Olark Chat Conversation  1.0
# 6                                 Last Activity_Other  1.0
# 7               Last Activity_Page Visited on Website  1.0
# 10  What is your current occupation_Working Profes...  1.0

# %%
x = sm.add_constant(x_train)
model = sm.Logit(y_train, x).fit()
model.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.477412
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              Converted   No. Observations:                 4283
# Model:                          Logit   Df Residuals:                     4271
# Method:                           MLE   Df Model:                           11
# Date:                Thu, 28 Jan 2021   Pseudo R-squ.:                  0.3103
# Time:                        22:15:49   Log-Likelihood:                -2044.8
# converged:                       True   LL-Null:                       -2964.6
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ========================================================================================================================
#                                                            coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------
# const                                                   -0.7704      0.204     -3.770      0.000      -1.171      -0.370
# Total Time Spent on Website                              1.0944      0.047     23.210      0.000       1.002       1.187
# Lead Source_Google                                       0.4226      0.091      4.658      0.000       0.245       0.600
# Lead Source_Olark Chat                                   1.6559      0.126     13.102      0.000       1.408       1.904
# Lead Source_Other                                        3.0469      0.157     19.435      0.000       2.740       3.354
# Do Not Email_Yes                                        -1.1575      0.195     -5.944      0.000      -1.539      -0.776
# Last Activity_Olark Chat Conversation                   -1.4999      0.193     -7.768      0.000      -1.878      -1.121
# Last Activity_Other                                     -0.6218      0.132     -4.700      0.000      -0.881      -0.362
# Last Activity_Page Visited on Website                   -0.4642      0.177     -2.626      0.009      -0.811      -0.118
# Last Activity_SMS Sent                                   1.0316      0.090     11.514      0.000       0.856       1.207
# What is your current occupation_Unemployed              -0.3219      0.201     -1.603      0.109      -0.716       0.072
# What is your current occupation_Working Professional     2.1538      0.268      8.048      0.000       1.629       2.678
# ========================================================================================================================
# """

# %%
x_train.drop(['What is your current occupation_Unemployed'], axis = 1, inplace=True)

# %%
vif = pd.DataFrame()
vif['Features'] = x_train.columns
vif['VIF'] = [variance_inflation_factor(x_train.values, i) for i in range(x_train.shape[1])]
vif['VIF'] = round(vif['VIF'])
vif = vif.sort_values('VIF',ascending = False)
vif
# Out:
#                                             Features  VIF
# 0                        Total Time Spent on Website  1.0
# 1                                 Lead Source_Google  1.0
# 2                             Lead Source_Olark Chat  1.0
# 3                                  Lead Source_Other  1.0
# 4                                   Do Not Email_Yes  1.0
# 5              Last Activity_Olark Chat Conversation  1.0
# 6                                Last Activity_Other  1.0
# 7              Last Activity_Page Visited on Website  1.0
# 8                             Last Activity_SMS Sent  1.0
# 9  What is your current occupation_Working Profes...  1.0

# %%
x = sm.add_constant(x_train)
model = sm.Logit(y_train, x).fit()
model.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.477709
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              Converted   No. Observations:                 4283
# Model:                          Logit   Df Residuals:                     4272
# Method:                           MLE   Df Model:                           10
# Date:                Thu, 28 Jan 2021   Pseudo R-squ.:                  0.3098
# Time:                        22:15:49   Log-Likelihood:                -2046.0
# converged:                       True   LL-Null:                       -2964.6
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ========================================================================================================================
#                                                            coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------
# const                                                   -1.0736      0.078    -13.678      0.000      -1.227      -0.920
# Total Time Spent on Website                              1.0944      0.047     23.213      0.000       1.002       1.187
# Lead Source_Google                                       0.4161      0.091      4.594      0.000       0.239       0.594
# Lead Source_Olark Chat                                   1.6596      0.126     13.132      0.000       1.412       1.907
# Lead Source_Other                                        3.0437      0.157     19.423      0.000       2.737       3.351
# Do Not Email_Yes                                        -1.1541      0.195     -5.923      0.000      -1.536      -0.772
# Last Activity_Olark Chat Conversation                   -1.4890      0.193     -7.717      0.000      -1.867      -1.111
# Last Activity_Other                                     -0.6229      0.132     -4.708      0.000      -0.882      -0.364
# Last Activity_Page Visited on Website                   -0.4687      0.177     -2.650      0.008      -0.815      -0.122
# Last Activity_SMS Sent                                   1.0193      0.089     11.431      0.000       0.845       1.194
# What is your current occupation_Working Professional     2.4625      0.186     13.228      0.000       2.098       2.827
# ========================================================================================================================
# """

# %% [markdown]
# - I think it should do the job, I have checked almost everything includes p values, vif, best features etc

# %%
Lreg.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
x_train.columns
# Out:
# Index(['Total Time Spent on Website', 'Lead Source_Google',
#        'Lead Source_Olark Chat', 'Lead Source_Other', 'Do Not Email_Yes',
#        'Last Activity_Olark Chat Conversation', 'Last Activity_Other',
#        'Last Activity_Page Visited on Website', 'Last Activity_SMS Sent',
#        'What is your current occupation_Working Professional'],
#       dtype='object')

# %%
x_test= x_test[x_train.columns]

# %%
y_predict_test =Lreg.predict(x_test)
y_predict_train = Lreg.predict(x_train)

# %%
score_test = accuracy_score(y_test, y_predict_test)
score_train = accuracy_score(y_train, y_predict_train)

# %%
print('Test score: ',score_test)
print('Train score', score_train)
# Out:
# Test score:  0.789760348583878
# Train score 0.7795937427037124

# %%
print(classification_report(y_test, y_predict_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.83      0.80       958
#            1       0.80      0.75      0.77       878
#
#     accuracy                           0.79      1836
#    macro avg       0.79      0.79      0.79      1836
# weighted avg       0.79      0.79      0.79      1836

# %%
matrix = confusion_matrix(y_test, y_predict_test)

# %%
matrix
# Out:
# array([[791, 167],
#        [219, 659]], dtype=int64)

# %%
y_prob_test = Lreg.predict_proba(x_test)[:,1]
y_prob_train = Lreg.predict_proba(x_train)[:,1]

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc, roc_curve

# %%
fpr, tpr, thresholds = roc_curve(y_train.values.reshape(-1,1), y_prob_train)

# %%
prob_score = roc_auc_score(y_train.values.reshape(-1,1), y_prob_train)
prob_score
# Out:
# 0.8523140893825162

# %%
roc_auc = auc(fpr, tpr)
roc_auc
# Out:
# 0.8523140893825162

# %%
plt.plot(fpr, tpr, color = 'b', label='Roc Curve (area = %2f)' %roc_auc)
plt.plot([0,1], [0,1], 'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate (Sensitivity)')
plt.title('ROC Example')
plt.legend(loc='lower right')  # to show the area in lower right
plt.show()

# %%
i = np.arange(len(tpr))
optimal_threshold = pd.DataFrame({'fpr' : pd.Series(fpr, index = i), 'tpr' : pd.Series(tpr, index = i), '1-fpr' : pd.Series(1-fpr, index=i),
                                  'tf' : pd.Series(tpr-(1-fpr), index=i),'threshold' : pd.Series(thresholds.round(2), index=i)})
abs(optimal_threshold).sort_values('tf', ascending=True).head()
# Out:
#           fpr       tpr     1-fpr        tf  threshold
# 674  0.217800  0.782120  0.782200  0.000080       0.44
# 673  0.217352  0.781632  0.782648  0.001016       0.44
# 675  0.219141  0.782120  0.780859  0.001261       0.44
# 672  0.216905  0.781632  0.783095  0.001463       0.44
# 676  0.219589  0.782609  0.780411  0.002197       0.44

# %%
from sklearn.preprocessing import binarize
y_predict_train = binarize(y_prob_train.reshape(-1,1), 0.44)

# %%
accuracy_score(y_predict_train.reshape(-1,1), y_train)
# Out:
# 0.7816950735465795

# %%
y_predict_test = binarize(y_prob_test.reshape(-1,1), 0.44)
accuracy_score(y_test, y_predict_test)
# Out:
# 0.7881263616557734

# %%
plt.plot(optimal_threshold.set_index('threshold').tpr)
plt.plot(optimal_threshold.set_index('threshold')['1-fpr'])

# %%
result = pd.DataFrame(data=[y_test.flatten(), y_predict_test.astype(int).flatten()]).T
result.columns = ['Actual Conversion', 'Predicted Conversion']
result.head()
# Out:
#    Actual Conversion  Predicted Conversion
# 0                  1                     0
# 1                  0                     1
# 2                  1                     0
# 3                  0                     0
# 4                  1                     1

# %%
score = pd.DataFrame(data=[y_test.flatten(), y_prob_test.flatten()]).T
score.columns = ['Actual Conversion', 'Lead Score']
score.head()
# Out:
#    Actual Conversion  Lead Score
# 0                1.0    0.228368
# 1                0.0    0.638546
# 2                1.0    0.123324
# 3                0.0    0.111605
# 4                1.0    0.751518
